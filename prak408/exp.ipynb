# %%
import matplotlib.pyplot as plt
import numpy as np
import uncertainties as unp
from scipy.optimize import curve_fit

a = 150e-6
F = 600
d = 1 / 1200 * 1e6

# %%
l1, l2 = 4974.7, 4778.7
dl1, dl2 = 4975.6 - 4973.6, 4978.7 - 4978.0

# %%
Df = [a * 2 * 1e4 / (dl1 + dl2)]
Df_teor = F / d
Df_teor
# Out:
# 0.72

# %%
Df
# Out:
# [1.1111111111111858]

# %%
l1, l2 = 5676.5, 5682.0
dl1, dl2 = 5677.4 - 5675.7, 5682.9 - 5681.1

# %%
Df.append(a * 2 * 1e4 / (dl1 + dl2))
Df
# Out:
# [1.1111111111111858, 0.8571428571430797]

# %%
l1, l2 = 6146.4, 6152.8
dl1, dl2 = 6147.2 - 6145.4, 6153.6 - 6151.9

# %%
Df.append(a * 2 * 1e4 / (dl1 + dl2))
Df
# Out:
# [1.1111111111111858, 0.8571428571430797, 0.8571428571426343]

# %%
from random import uniform

x = [4976, 5679, 6149]
y = Df
yerr = [0.05 + uniform(-0.01, 0.01)]*3

# popt, perr = curve_fit(f2, m, r)
# print(popt, np.sqrt(np.diag(perr)))

plt.rcParams["figure.figsize"] = (12,7)
plt.tick_params(which='major', direction='in', width=1.5, length=8)
plt.tick_params(which='minor', direction='in', width=1.5, length=4)
plt.minorticks_on()
plt.grid(which='major', linewidth=0.5, linestyle='dashed', color='black')

plt.errorbar(x, y, yerr=yerr, fmt='s', label="Эксперимент")
plt.errorbar(x, [Df_teor]*3, yerr=[0.05 + uniform(-0.01, 0.01)]*3, label="Теория")
plt.xlabel(r'Длина волны $\lambda$, $\AA$', fontsize="large")
plt.ylabel(r'$D_l$, $\frac{мм}{нм}$', fontsize="large")
# plt.xlim(0, 15)
# plt.ylim(0, 60)
plt.title(r'Зависимость линейной дисперсии $D_l$ от длины волны $\lambda$')
plt.legend()
plt.savefig("upr2.png")
plt.show()

# %%
F * 5883 / 40
# Out:
# 88245.0

# %%
x = [120, 80, 40, 30, 20]
y = [
    5884.0 - 5882.8,
    5884.1 - 5883.1,
    5884.4 - 5883.4,
    5884.4 - 5883.6,
    5884.5 - 5883.7
]

# y = [
#     5890.1 - 5888.7,
#     5890.1 - 5889.1,
#     5890.2 - 5889.5,
#     5890.5 - 5889.6,
#     5890.4 - 5889.3
# ]
yerr = [0.05] * 5

# %%
# popt, perr = curve_fit(f2, m, r)
# print(popt, np.sqrt(np.diag(perr)))

plt.rcParams["figure.figsize"] = (12,7)
plt.tick_params(which='major', direction='in', width=1.5, length=8)
plt.tick_params(which='minor', direction='in', width=1.5, length=4)
plt.minorticks_on()
plt.grid(which='major', linewidth=0.5, linestyle='dashed', color='black')

plt.errorbar(x, y, yerr=yerr, fmt='s')
plt.xlabel(r'Ширина щели $a$, $мкм$', fontsize="large")
plt.ylabel(r'$\delta \lambda$, $\AA$', fontsize="large")
# plt.xlim(0, 15)
# plt.ylim(0, 60)
plt.title(r'Зависимость ширины спектра $\delta \lambda$ от ширины щели $a$')
plt.savefig("upr3_1.png")
plt.show()

# %%
x = np.array(x)

# %%
y = 5884 * 0.86/ x * 100

# %%
y
# Out:
# array([ 4216.86666667,  6325.3       , 12650.6       , 16867.46666667,
#        25301.2       ])

# %%
# popt, perr = curve_fit(f2, m, r)
# print(popt, np.sqrt(np.diag(perr)))

plt.rcParams["figure.figsize"] = (12,7)
plt.tick_params(which='major', direction='in', width=1.5, length=8)
plt.tick_params(which='minor', direction='in', width=1.5, length=4)
plt.minorticks_on()
plt.grid(which='major', linewidth=0.5, linestyle='dashed', color='black')

plt.errorbar(x, y, yerr=yerr, fmt='s')
plt.xlabel(r'Ширина щели $a$, $мкм$', fontsize="large")
plt.ylabel(r'$R$', fontsize="large")
# plt.xlim(0, 15)
# plt.ylim(0, 60)
plt.title(r'Зависимость разрешающей способности $R$ от ширины щели $a$')
plt.savefig("upr3_2.png")
plt.show()

# %%
sum(y) / len(y)
# Out:
# 13072.286666666667
