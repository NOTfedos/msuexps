# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np
from math import log
import os


U1 = [0, 1, 2, 3, 3.5, 4, 5, 6, 7, 8, 8.5, 9, 9.5 ,10, 11, 12, 13, 14, 15]
I1 = [0, 0.04, 0.24, 0.43, 0.52, 0.50, 0.23, 0.24, 0.40, 0.52, 0.54, 0.55, 0.54, 0.52, 0.48, 0.41, 0.46, 0.60, 0.61]

U2 = [0, 0.5, 1.0, 1.5, 2.0 ,2.5, 3.0]
I2 = [0.42, 0.35, 0.29, 0.20, 0.12, 0.04, 0.01]

plt.errorbar(U1, I1, fmt='s', label=r'Анодная характеристика, $U_{т} = 2В, I_{накала} = 2.14А$')
# plt.errorbar(U2, I2, fmt='s', label=r'Характеристика задержки, $U_{уск} = 1.5В$')
# plt.errorbar(U1, I1, fmt='s', label=r'Характеристика задержки, $U_{уск} = 5В$')
plt.xlabel(r'U, В')
plt.ylabel(r'I, мкА')
plt.title(r'ВАХ ртути при температуре (T = 82C)')
plt.legend()
plt.savefig(os.path.join(".", "ims", "VAX_Hg_T82_kek.png"))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
5.2 / (11.2 - 5.2) * (240 * 1e-9 / 0.4e-2 / log(40))**2
# Out:
# 2.292797328424562e-10

# %%
19 / (33 - 19) * (75 * 1e-9 / 0.4e-2 / log(40))**2
# Out:
# 3.506220159045544e-11

# %%
7.75 / 2.6 * 3.5
# Out:
# 10.432692307692308
