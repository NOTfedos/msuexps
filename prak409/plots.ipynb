# %%
import matplotlib.pyplot as plt
import numpy as np
import uncertainties as unp
from scipy.optimize import curve_fit

# %%
x = [111.4, 112.2, 118.3, 118.1, 33.0, 51.5, 66.7, 94.5, 110.3]
x_err = [2.7, 4.8, 4.2, 5.7, 0.7, 2.3, 3.0, 4.5, 5.7]
y = [40849, 46456, 51311, 51883, 3425, 8846, 15795, 33903, 47618]

x = np.array(x)
x_err = np.array(x_err)
y = np.array(y)

# %%
def f(x, a, b):
    return a*x + b

# %%
x = x**2
x_err = 2 * x**(0.5) * x_err

# %%
popt, perr = curve_fit(f, x, y)
print(popt, np.sqrt(np.diag(perr)))

plt.rcParams["figure.figsize"] = (12,7)
plt.tick_params(which='major', direction='in', width=1.5, length=8)
plt.tick_params(which='minor', direction='in', width=1.5, length=4)
plt.minorticks_on()
plt.grid(which='major', linewidth=0.5, linestyle='dashed', color='black')

plt.errorbar(x, y, xerr=x_err, fmt='s')
plt.plot(x, f(x, *popt))
plt.xlabel(r'$b^2$, ${мкм}^2$', fontsize="large")
plt.ylabel(r'$I$, отн. ед.', fontsize="large")
plt.title(r'Зависимость интенсивности в центре дифракционной картины от ширины щели')
plt.savefig("I(b_2).png")
plt.show()
# Out:
# [   3.71929446 -638.14743063] [1.51369226e-01 1.56223891e+03]

# %%
n = [2, 3, 4, 1]
y = [7510, 12809, 21818, 1647]
n = np.array(n)
y = np.array(y)
n = n**2

# %%
popt, perr = curve_fit(f, n, y)
print(popt, np.sqrt(np.diag(perr)))

plt.rcParams["figure.figsize"] = (12,7)
plt.tick_params(which='major', direction='in', width=1.5, length=8)
plt.tick_params(which='minor', direction='in', width=1.5, length=4)
plt.minorticks_on()
plt.grid(which='major', linewidth=0.5, linestyle='dashed', color='black')

plt.errorbar(n, y, fmt='s')
plt.plot(n, f(n, *popt))
plt.xlabel(r'$N^2$', fontsize="large")
plt.ylabel(r'$I$, отн. ед.', fontsize="large")
plt.title(r'Зависимость интенсивности в центре дифракционной картины от количества щелей')
plt.savefig("I(N_2).png")
plt.show()
# Out:
# [ 6581.2000053  -5507.00001324] [ 582.03804049 1593.97682553]
